# %% [markdown]
# # Automatic Detection of Hot-Rolled Steel Strips Surface Defects using Convolutional Neural Network
# #### This project aims to automatically detect surface defects in Hot-Rolled Steel Strips such as rolled-in scale, patches, crazing, pitted surface, inclusion and scratches (as depicted in the image below). A Convolutional Neural Network Model is developed and trained on the NEU Metal Surface Defects Database which contains 1800 grayscale images with 300 samples of each of the six different kinds of surface defects.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow-gpu
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow-gpu in /usr/local/lib/python3.8/dist-packages (2.11.0)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.14.1)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (3.1.0)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (22.12.6)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.6.3)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (14.0.6)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (3.3.0)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.21.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.15.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (0.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (57.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (0.28.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (4.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.51.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (3.19.6)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (1.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (21.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (2.1.1)
# Requirement already satisfied: keras<2.12,>=2.11.0 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (2.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from tensorflow-gpu) (0.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.8/dist-packages (from astunparse>=1.6.0->tensorflow-gpu) (0.38.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (2.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard<2.12,>=2.11->tensorflow-gpu) (1.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (5.2.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (4.13.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.11.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-gpu) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-gpu) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-gpu) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow-gpu) (3.0.9)

# %%
# !nvidia-smi
# Out:
# Tue Dec 13 11:18:48 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    29W /  70W |   1926MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 1. Importing Relevant Libraries

# %%
import os
import numpy as np
import pandas as pd
import tensorflow as tf
import seaborn as sns
import matplotlib.pyplot as plt
from keras.optimizers import RMSprop
from keras_preprocessing.image import ImageDataGenerator
from sklearn.datasets import load_files
from keras.utils import np_utils
from keras_preprocessing.image import array_to_img, img_to_array, load_img
from keras.layers import BatchNormalization

# %% [markdown]
# ## 2. Importing the NEU Metal Surface Defect Dataset

# %%
train_dir = '/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data/train'
val_dir = '/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data/valid'
test_dir='/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data/test'
print("Path: ",os.listdir("/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data"))
print("Train: ",os.listdir("/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data/train"))
print("Test: ",os.listdir("/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data/test"))
print("Validation: ",os.listdir("/content/drive/MyDrive/Datasets/NEU Metal Surface Defects Data/valid"))
# Out:
# Path:  ['valid', 'train', 'test']
# Train:  ['Inclusion', 'Patches', 'Rolled', 'Pitted', 'Scratches', 'Crazing']
# Test:  ['Patches', 'Scratches', 'Pitted', 'Inclusion', 'Crazing', 'Rolled']
# Validation:  ['Patches', 'Scratches', 'Crazing', 'Pitted', 'Inclusion', 'Rolled']

# %% [markdown]
# #### For each Class, the Training Data includes 276 Images, Validation & Test sets have 12 images each.

# %%
print("Inclusion Defect")
print("Training Images:",len(os.listdir(train_dir+'/'+'Inclusion')))
print("Testing Images:",len(os.listdir(test_dir+'/'+'Inclusion')))
print("Validation Images:",len(os.listdir(val_dir+'/'+'Inclusion')))
# Out:
# Inclusion Defect
# Training Images: 210
# Testing Images: 45
# Validation Images: 45

# %% [markdown]
# ## 3. Data Pre-processing

# %%
# Rescaling all Images by 1./255
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# Training images are put in batches of 10
train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(200, 200),
        batch_size=10,
        class_mode='categorical')

# Validation images are put in batches of 10
validation_generator = test_datagen.flow_from_directory(
        val_dir,
        target_size=(200, 200),
        batch_size=10,
        class_mode='categorical')
# Out:
# Found 1260 images belonging to 6 classes.
# Found 270 images belonging to 6 classes.

# %% [markdown]
# #### Setting upper Limit of Max 98% training accuracy

# %%
class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if(logs.get('accuracy') > 0.98 ):
            print("\nReached 98% accuracy so cancelling training!")
            self.model.stop_training = True

# %% [markdown]
# ## 4. Defining the CNN Architecture

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu',
                           input_shape=(200, 200, 3)),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2, 2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(128, activation='relu'),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(6, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 198, 198, 32)      896
#
#  max_pooling2d_6 (MaxPooling  (None, 99, 99, 32)       0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_7 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 46, 46, 128)       73856
#
#  max_pooling2d_8 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  flatten_2 (Flatten)         (None, 67712)             0
#
#  dense_4 (Dense)             (None, 128)               8667264
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 8,761,286
# Trainable params: 8,761,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
tf.keras.utils.plot_model(
    model,
    to_file='cnn_architecture.png',
    show_shapes=True)

# %% [markdown]
# ## 5. Training the Defined CNN Model

# %%
callbacks = myCallback()
history = model.fit(train_generator,
        batch_size = 16,
        epochs=30,
        validation_data=validation_generator,
        callbacks=[callbacks],
        verbose=1, shuffle=True)
# Out:
# Epoch 1/30
# 126/126 [==============================] - 16s 112ms/step - loss: 1.8148 - accuracy: 0.2310 - val_loss: 1.4719 - val_accuracy: 0.4815
# Epoch 2/30
# 126/126 [==============================] - 14s 110ms/step - loss: 1.3374 - accuracy: 0.4849 - val_loss: 1.0524 - val_accuracy: 0.6444
# Epoch 3/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.9991 - accuracy: 0.6302 - val_loss: 0.7601 - val_accuracy: 0.7815
# Epoch 4/30
# 126/126 [==============================] - 14s 109ms/step - loss: 0.8219 - accuracy: 0.7262 - val_loss: 1.0446 - val_accuracy: 0.5630
# Epoch 5/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.6798 - accuracy: 0.7659 - val_loss: 0.3802 - val_accuracy: 0.9074
# Epoch 6/30
# 126/126 [==============================] - 14s 110ms/step - loss: 0.6180 - accuracy: 0.8119 - val_loss: 0.3538 - val_accuracy: 0.9148
# Epoch 7/30
# 126/126 [==============================] - 14s 112ms/step - loss: 0.5301 - accuracy: 0.8413 - val_loss: 0.2830 - val_accuracy: 0.9148
# Epoch 8/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.5030 - accuracy: 0.8675 - val_loss: 0.8863 - val_accuracy: 0.6444
# Epoch 9/30
# 126/126 [==============================] - 13s 107ms/step - loss: 0.4236 - accuracy: 0.8746 - val_loss: 0.2454 - val_accuracy: 0.9222
# Epoch 10/30
# 126/126 [==============================] - 16s 123ms/step - loss: 0.3983 - accuracy: 0.8952 - val_loss: 0.5270 - val_accuracy: 0.8630
# Epoch 11/30
# 126/126 [==============================] - 13s 107ms/step - loss: 0.4173 - accuracy: 0.8849 - val_loss: 0.3569 - val_accuracy: 0.9037
# Epoch 12/30
# 126/126 [==============================] - 14s 109ms/step - loss: 0.3133 - accuracy: 0.9159 - val_loss: 0.2291 - val_accuracy: 0.9296
# Epoch 13/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.2952 - accuracy: 0.9175 - val_loss: 0.1473 - val_accuracy: 0.9444
# Epoch 14/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.2720 - accuracy: 0.9167 - val_loss: 0.2261 - val_accuracy: 0.9370
# Epoch 15/30
# 126/126 [==============================] - 13s 107ms/step - loss: 0.2718 - accuracy: 0.9238 - val_loss: 0.1253 - val_accuracy: 0.9444
# Epoch 16/30
# 126/126 [==============================] - 14s 107ms/step - loss: 0.2364 - accuracy: 0.9302 - val_loss: 0.1761 - val_accuracy: 0.9222
# Epoch 17/30
# 126/126 [==============================] - 13s 107ms/step - loss: 0.2666 - accuracy: 0.9246 - val_loss: 0.8319 - val_accuracy: 0.7667
# Epoch 18/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.1969 - accuracy: 0.9317 - val_loss: 0.2962 - val_accuracy: 0.9148
# Epoch 19/30
# 126/126 [==============================] - 14s 107ms/step - loss: 0.2232 - accuracy: 0.9325 - val_loss: 0.2152 - val_accuracy: 0.9333
# Epoch 20/30
# 126/126 [==============================] - 13s 107ms/step - loss: 0.3195 - accuracy: 0.9381 - val_loss: 0.2560 - val_accuracy: 0.9259
# Epoch 21/30
# 126/126 [==============================] - 13s 106ms/step - loss: 0.2308 - accuracy: 0.9317 - val_loss: 0.2231 - val_accuracy: 0.9333
# Epoch 22/30
# 126/126 [==============================] - 13s 105ms/step - loss: 0.1974 - accuracy: 0.9381 - val_loss: 0.2986 - val_accuracy: 0.9259
# Epoch 23/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.1968 - accuracy: 0.9413 - val_loss: 0.2458 - val_accuracy: 0.9370
# Epoch 24/30
# 126/126 [==============================] - 13s 106ms/step - loss: 0.1734 - accuracy: 0.9524 - val_loss: 0.2467 - val_accuracy: 0.9296
# Epoch 25/30
# 126/126 [==============================] - 15s 122ms/step - loss: 0.2203 - accuracy: 0.9397 - val_loss: 0.2267 - val_accuracy: 0.9481
# Epoch 26/30
# 126/126 [==============================] - 13s 106ms/step - loss: 0.1506 - accuracy: 0.9548 - val_loss: 0.1954 - val_accuracy: 0.9444
# Epoch 27/30
# 126/126 [==============================] - 13s 106ms/step - loss: 0.1995 - accuracy: 0.9389 - val_loss: 0.2370 - val_accuracy: 0.9444
# Epoch 28/30
# 126/126 [==============================] - 13s 106ms/step - loss: 0.1778 - accuracy: 0.9556 - val_loss: 0.2270 - val_accuracy: 0.9296
# Epoch 29/30
# 126/126 [==============================] - 14s 108ms/step - loss: 0.1729 - accuracy: 0.9643 - val_loss: 0.2890 - val_accuracy: 0.9296
# Epoch 30/30
# 126/126 [==============================] - 13s 106ms/step - loss: 0.3097 - accuracy: 0.9405 - val_loss: 0.6614 - val_accuracy: 0.8333

# %% [markdown]
# ## 6. Analysing the Accuracy & the Loss Curves

# %%
sns.set_style("whitegrid")
plt.subplot(211)  
plt.plot(history.history['accuracy'])  
plt.plot(history.history['val_accuracy'])  
plt.title('model accuracy')  
plt.ylabel('accuracy')  
plt.xlabel('epoch')  
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
sns.set_style("whitegrid")
plt.subplot(212)  
plt.plot(history.history['loss'])  
plt.plot(history.history['val_loss'])  
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')  
plt.show()

# %% [markdown]
# ## 7. Test Result visualization

# %%
# Loading file names & their respective target labels into numpy array
def load_dataset(path):
    data = load_files(path)
    files = np.array(data['filenames'])
    targets = np.array(data['target'])
    target_labels = np.array(data['target_names'])
    return files,targets,target_labels
x_test, y_test,target_labels = load_dataset(test_dir)
no_of_classes = len(np.unique(y_test))
no_of_classes
# Out:
# 6

# %%
y_test = np_utils.to_categorical(y_test,no_of_classes)

# %%
def convert_image_to_array(files):
    images_as_array=[]
    for file in files:
        # Convert to Numpy Array
        images_as_array.append(img_to_array(load_img(file)))
    return images_as_array

x_test = np.array(convert_image_to_array(x_test))
print('Test set shape : ',x_test.shape)
# Out:
# Test set shape :  (270, 200, 200, 3)

# %%
x_test = x_test.astype('float32')/255

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=1)
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# 9/9 [==============================] - 0s 19ms/step - loss: 0.6648 - accuracy: 0.8778
# Test: accuracy = 0.877778  ;  loss = 0.664763

# %% [markdown]
# ## Results of Hot-Rolled Steel Strips Surface Defect Detection

# %%
# Plotting Random Sample of test images, their predicted labels, and ground truth
y_pred = model.predict(x_test)
fig = plt.figure(figsize=(10, 10))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=16, replace=False)):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_pred[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(target_labels[pred_idx], target_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
# Out:
# 9/9 [==============================] - 1s 27ms/step
